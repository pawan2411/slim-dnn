# %% [markdown]
# $\newcommand{\vct}[1]{\boldsymbol{#1}}
# \newcommand{\mtx}[1]{\mathbf{#1}}
# \newcommand{\tr}{^\mathrm{T}}
# \newcommand{\reals}{\mathbb{R}}
# \newcommand{\lpa}{\left(}
# \newcommand{\rpa}{\right)}
# \newcommand{\lsb}{\left[}
# \newcommand{\rsb}{\right]}
# \newcommand{\lbr}{\left\lbrace}
# \newcommand{\rbr}{\right\rbrace}
# \newcommand{\fset}[1]{\lbr #1 \rbr}
# \newcommand{\pd}[2]{\frac{\partial #1}{\partial #2}}$
#
# # Background
#
# A neural network is composed of a number of layers, each implementing some transformation. The typical high level implementation of a single such layer (of basic type -> linear transformation plus non-linearity) can be formulated as follows:
#
# \begin{equation}
#     \vct{y} = \vct{f}(\mtx{W} \vct{x} + \vct{b})
#     \qquad
#     \Leftrightarrow
#     \qquad
#     y_k = f\lpa\sum_{d=1}^D \lpa W_{kd} x_d \rpa + b_k \rpa
# \end{equation}
#
# where $\mtx{W}$ and $\vct{b}$ parameterise an affine transformation, and $f$ is a function applied elementwise to the result of the affine transformation. For example a common choice for $f$ is the rectifier linear unit:
#
# \begin{equation}
#   f(u) = max(0,u)
# \end{equation}
#
# One can stack an arbitrary number of such transformations, followed by an output layer. This means we can combine implementations of `AffineLayer` class with any non-linear function applied to the outputs just by implementing a layer object for the relevant non-linearity and then stacking the two layers together.
#
# To give a concrete example, in the `mlp.layers` module there is a definition for a `ReluLayer` equivalent to the following (documentation strings have been removed here for brevity)
#
# ```python
# class ReluLayer(Layer):
#
#     def fprop(self, inputs):
#         return np.maximum(inputs, 0.)
#
#     def bprop(self, inputs, outputs, grads_wrt_outputs):
#         return (outputs > 0) * grads_wrt_outputs
# ```
#
# As you can see this `ReluLayer` class has a very lightweight definition, defining just two key methods:
#
#   * `fprop` which takes a batch of activations at the input to the layer and forward propagates them to produce activations at the outputs (directly equivalently to the `fprop` method of `AffineLayer`),
#   * `brop` which takes a batch of gradients with respect to the outputs of the layer and back-propagates them to calculate gradients with respect to the inputs of the layer (explained in more detail below).
#
# This `ReluLayer` class only implements the rectified linear transformation and so does not have any parameters. Therefore unlike `AffineLayer` it is derived directly from the base `Layer` class rather than `LayerWithParameters` and does not need to implement `grads_wrt_params` or `params` methods.
#
# To create a model consisting of an affine transformation followed by applying an elementwise rectified linear transformation you can first create a list of the two layer objects (in the order they are applied from inputs to outputs) and then use this to instantiate a new `MultipleLayerModel` object:
#
# ```python
# from mlp.layers import AffineLayer, ReluLayer
# from mlp.models import MultipleLayerModel
#
# layers = [AffineLayer(input_dim, output_dim), ReluLayer()]
# model = MultipleLayerModel(layers)
# ```
#
# You can also stack an arbitrarily long sequence of layers together to produce deeper models. For instance the following would define a model consisting of three pairs of affine and rectified linear transformations.
#
# ```python
# model = MultipleLayerModel([
#     AffineLayer(input_dim, hidden_dim), ReluLayer(),
#     AffineLayer(hidden_dim, hidden_dim), ReluLayer(),
#     AffineLayer(hidden_dim, output_dim), ReluLayer(),
# ])
# ```
#
# ## Back-propagation of gradients
#  The `bprop` method takes gradients of an error function with respect to the *outputs* of a layer and uses these gradients to calculate gradients of the error function with respect to the *inputs* of a layer. As the inputs to a non-input layer in a multiple-layer model consist of the outputs of the previous layer, this means we can calculate the gradients of the error function with respect to the outputs of every layer in the model by iteratively propagating the gradients backwards through the layers of the model (i.e. from the last to first layer).
#
# For a layer with parameters, the gradients with respect to the layer outputs are required to calculate gradients with respect to the layer parameters. Therefore by combining back-propagation of gradients through the model with computing the gradients with respect to parameters in the relevant layers one can calculate gradients of the error function with respect to all of the parameters of a multiple-layer model in a very efficient manner.

# %% [markdown]
# # Task 1: Exploring activation functions
#
# Among other minor things, you are expected to implement the Scaled Exponential Linear Unit (SELU), Gaussian Error Linear Unit (GELU), and the Inverse Square Root Linear Unit (ISRLU) layers (all in the mlp.layers module). Then run several basic experiments on the MNIST benchmark.
#
# Below you are given basic blocks (how to build the model as a whole, define data providers, add optimiser, etc.) to get the whole training pipeline ready.
#
# Your tasks here would be:
#
# 1-1) Add the missing layers mentioned above. Show how you arrived at the derivative of the GELU function (2-3 lines of the equation will suffice).
#
# 1-2) Establish a baseline network for MNIST using stochastic gradient descent (SGD) and the ReLU activation function. Justify your choices of hyperparameters and hyperparameter explorations.
#
# 1-3) Modify the baseline network to one that uses each of the above activation functions. Your main aim is to compare the generalization performance of each of these activation functions as well as discover the best possible network configuration when the only available options to choose from are the activation functions and their hyperparameters. Explain your findings.
#
# 1-4) Some of these activations have been shown to improve training when paired with special initialisation strategies. Investigate which of them do, implement them and rerun the corresponding optimal networks found in the previous excercise. Explain your findings.
#
# 1-5) Select the optimal network from the exploration above. List possible improvements to the network to achieve better a) accuracy, b) training speed and c) inference speed. Ensure to add a brief explanation for how each of your suggestions can result in the relevant improvement.

# %%
import numpy as np
import matplotlib.pyplot as plt
import logging
from mlp.layers import AffineLayer, ReluLayer, SeluLayer, GeluLayer, IsrlLayer
from mlp.errors import CrossEntropyError, CrossEntropySoftmaxError
from mlp.models import SingleLayerModel, MultipleLayerModel
from mlp.initialisers import UniformInit
from mlp.learning_rules import GradientDescentLearningRule
from mlp.data_providers import MNISTDataProvider
from mlp.optimisers import Optimiser
# %matplotlib inline
plt.style.use('ggplot')

# Seed a random number generator
seed = 6102016 
rng = np.random.RandomState(seed)

# Set up a logger object to print info about the training run to stdout
logger = logging.getLogger()
logger.setLevel(logging.INFO)
logger.handlers = [logging.StreamHandler()]

# Create data provider objects for the MNIST data set
train_data = MNISTDataProvider('train', rng=rng)
valid_data = MNISTDataProvider('valid', rng=rng)
input_dim, output_dim = 784, 10

# %% [markdown]
# To minimise replication of code and allow you to run experiments more quickly a helper function is provided below which trains a model and plots the evolution of the error and classification accuracy of the model (on both training and validation sets) over training.
#
# Running the cell below will create a model consisting of an affine layer followed by a softmax transformation and trains it on the MNIST data set by minimising the multi-class cross entropy error function using a basic gradient descent learning rule. By using the helper function defined below, at the end of the training curves of the evolution of the error function and also classification accuracy of the model over the training epochs will be plotted.
#
# You should try running the code for various settings of the training hyperparameters defined at the beginning of the cell to get a feel for how these affect how training proceeds. You may wish to create multiple copies of the cell below to allow you to keep track of and compare the results across different hyperparameter settings.

# %%
def train_model_and_plot_stats(
        model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval):

    # As well as monitoring the error over training also monitor classification
    # accuracy i.e. proportion of most-probable predicted classes being equal to targets
    data_monitors={'acc': lambda y, t: (y.argmax(-1) == t.argmax(-1)).mean()}

    # Use the created objects to initialise a new Optimiser instance.
    optimiser = Optimiser(
        model, error, learning_rule, train_data, valid_data, data_monitors)

    # Run the optimiser for 5 epochs (full passes through the training set)
    # printing statistics every epoch.
    stats, keys, run_time = optimiser.train(num_epochs=num_epochs, stats_interval=stats_interval)

    # Plot the change in the validation and training set error over training.
    fig_1 = plt.figure(figsize=(8, 4))
    ax_1 = fig_1.add_subplot(111)
    for k in ['error(train)', 'error(valid)']:
        ax_1.plot(np.arange(1, stats.shape[0]) * stats_interval, 
                  stats[1:, keys[k]], label=k)
    ax_1.legend(loc=0)
    ax_1.set_xlabel('Epoch number')

    # Plot the change in the validation and training set accuracy over training.
    fig_2 = plt.figure(figsize=(8, 4))
    ax_2 = fig_2.add_subplot(111)
    for k in ['acc(train)', 'acc(valid)']:
        ax_2.plot(np.arange(1, stats.shape[0]) * stats_interval, 
                  stats[1:, keys[k]], label=k)
    ax_2.legend(loc=0)
    ax_2.set_xlabel('Epoch number')
    
    return stats, keys, run_time, fig_1, ax_1, fig_2, ax_2

# %% [markdown]
# Below we describe how to build multiple-layer model architectures for the MNIST classification task.
#
# ```python
# layers = [
#     AffineLayer(input_dim, 100),
#     ReluLayer(),
#     AffineLayer(100, output_dim),
#     ReluLayer()
# ]
# ```
#
# An example cell:

# %%
# disable logging by setting handler to dummy object
logger.handlers = [logging.NullHandler()]

# %% [markdown]
# #RELU

# %%
# Set training run hyperparameters
batch_size = 100  # number of data points in a batch
num_epochs = 100  # number of training epochs to perform
stats_interval = 5  # epoch interval between recording and printing stats
learning_rate = 0.8  # learning rate for gradient descent

init_scales = [0.1]  # scale for random parameter initialisation
final_errors_train = []
final_errors_valid = []
final_accs_train = []
final_accs_valid = []

for init_scale in init_scales:

    print('-' * 80)
    print(f'learning_rate={learning_rate} init_scale={init_scale}')
    print('-' * 80)
    # Reset random number generator and data provider states on each run
    # to ensure reproducibility of results
    rng.seed(seed)
    train_data.reset()
    valid_data.reset()

    # Alter data-provider batch size
    train_data.batch_size = batch_size 
    valid_data.batch_size = batch_size

    # Create a parameter initialiser which will sample random uniform values
    # from [-init_scale, init_scale]
    param_init = UniformInit(-init_scale, init_scale, rng=rng)

    # Create a model with two affine layers
    hidden_dim = 100
    model = MultipleLayerModel([
        AffineLayer(input_dim, hidden_dim, param_init, param_init),
        IsrlLayer(),
        AffineLayer(hidden_dim, output_dim, param_init, param_init)
    ])

    # Initialise a cross entropy error object
    error = CrossEntropySoftmaxError()

    # Use a basic gradient descent learning rule
    learning_rule = GradientDescentLearningRule(learning_rate=learning_rate)

    stats, keys, run_time, fig_1, ax_1, fig_2, ax_2 = train_model_and_plot_stats(
        model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval)
    plt.show()

    print(f'    final error(train) = {stats[-1, keys["error(train)"]]:.2e}')
    print(f'    final error(valid) = {stats[-1, keys["error(valid)"]]:.2e}')
    print(f'    final acc(train)   = {stats[-1, keys["acc(train)"]]:.2e}')
    print(f'    final acc(valid)   = {stats[-1, keys["acc(valid)"]]:.2e}')
    print(f'    run time per epoch = {run_time * 1. / num_epochs:.2f}')

    final_errors_train.append(stats[-1, keys['error(train)']])
    final_errors_valid.append(stats[-1, keys['error(valid)']])
    final_accs_train.append(stats[-1, keys['acc(train)']])
    final_accs_valid.append(stats[-1, keys['acc(valid)']])
# Out:
# --------------------------------------------------------------------------------
# learning_rate=0.8 init_scale=0.1
# --------------------------------------------------------------------------------
# Experiment Progress:   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  20%|█▉        | 99/500 [00:00<00:00, 984.98it/s]
# Epoch Progress:  42%|████▏     | 210/500 [00:00<00:00, 1056.13it/s]/Users/pawan.rajpoot/Downloads/dnn-test-slim/mlp/errors.py:170: RuntimeWarning: invalid value encountered in subtract
#   probs = np.exp(outputs - outputs.max(-1)[:, None])
#
# Epoch Progress:  64%|██████▍   | 320/500 [00:00<00:00, 1070.00it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 919.87it/s]
# Experiment Progress:   1%|          | 1/100 [00:00<00:55,  1.79it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  22%|██▏       | 109/500 [00:00<00:00, 1082.94it/s]
# Epoch Progress:  44%|████▍     | 219/500 [00:00<00:00, 1090.94it/s]
# Epoch Progress:  66%|██████▌   | 330/500 [00:00<00:00, 1095.47it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 934.17it/s]
# Experiment Progress:   2%|▏         | 2/100 [00:01<00:54,  1.81it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  22%|██▏       | 111/500 [00:00<00:00, 1107.39it/s]
# Epoch Progress:  44%|████▍     | 222/500 [00:00<00:00, 1068.52it/s]
# Epoch Progress:  67%|██████▋   | 333/500 [00:00<00:00, 1086.44it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 932.98it/s]
# Experiment Progress:   3%|▎         | 3/100 [00:01<00:53,  1.82it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  21%|██▏       | 107/500 [00:00<00:00, 1062.38it/s]
# Epoch Progress:  43%|████▎     | 214/500 [00:00<00:00, 1065.10it/s]
# Epoch Progress:  64%|██████▍   | 322/500 [00:00<00:00, 1067.23it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 912.73it/s]
# Experiment Progress:   4%|▍         | 4/100 [00:02<00:53,  1.81it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  22%|██▏       | 108/500 [00:00<00:00, 1074.21it/s]
# Epoch Progress:  43%|████▎     | 217/500 [00:00<00:00, 1080.51it/s]
# Epoch Progress:  65%|██████▌   | 326/500 [00:00<00:00, 1069.85it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 922.93it/s]
# Experiment Progress:   5%|▌         | 5/100 [00:03<01:03,  1.49it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  21%|██        | 103/500 [00:00<00:00, 1027.12it/s]
# Epoch Progress:  41%|████▏     | 207/500 [00:00<00:00, 1033.56it/s]
# Epoch Progress:  62%|██████▏   | 312/500 [00:00<00:00, 1037.53it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 877.63it/s]
# Experiment Progress:   6%|▌         | 6/100 [00:03<01:00,  1.56it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  21%|██        | 103/500 [00:00<00:00, 1022.85it/s]
# Epoch Progress:  41%|████▏     | 207/500 [00:00<00:00, 1029.64it/s]
# Epoch Progress:  62%|██████▏   | 310/500 [00:00<00:00, 1012.97it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 883.98it/s]
# Experiment Progress:   7%|▋         | 7/100 [00:04<00:57,  1.61it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  21%|██        | 106/500 [00:00<00:00, 1053.58it/s]
# Epoch Progress:  42%|████▏     | 212/500 [00:00<00:00, 1046.91it/s]
# Epoch Progress:  63%|██████▎   | 317/500 [00:00<00:00, 1038.11it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 861.99it/s]
# Experiment Progress:   8%|▊         | 8/100 [00:04<00:56,  1.64it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  21%|██        | 104/500 [00:00<00:00, 1031.33it/s]
# Epoch Progress:  42%|████▏     | 208/500 [00:00<00:00, 1023.24it/s]
# Epoch Progress:  62%|██████▏   | 311/500 [00:00<00:00, 1025.18it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 886.66it/s]
# Experiment Progress:   9%|▉         | 9/100 [00:05<00:54,  1.67it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  21%|██        | 105/500 [00:00<00:00, 1044.76it/s]
# Epoch Progress:  42%|████▏     | 211/500 [00:00<00:00, 1051.79it/s]
# Epoch Progress:  63%|██████▎   | 317/500 [00:00<00:00, 1044.54it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 892.40it/s]
# Experiment Progress:  10%|█         | 10/100 [00:06<01:02,  1.44it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  20%|██        | 102/500 [00:00<00:00, 1009.86it/s]
# Epoch Progress:  41%|████      | 203/500 [00:00<00:00, 948.70it/s]
# Epoch Progress:  60%|█████▉    | 299/500 [00:00<00:00, 918.89it/s]
# Epoch Progress:  78%|███████▊  | 392/500 [00:00<00:00, 881.98it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 749.69it/s]
# Experiment Progress:  11%|█         | 11/100 [00:07<01:01,  1.45it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  16%|█▋        | 82/500 [00:00<00:00, 819.15it/s]
# Epoch Progress:  33%|███▎      | 166/500 [00:00<00:00, 830.62it/s]
# Epoch Progress:  50%|█████     | 251/500 [00:00<00:00, 837.84it/s]
# Epoch Progress:  67%|██████▋   | 335/500 [00:00<00:00, 837.30it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 734.68it/s]
# Experiment Progress:  12%|█▏        | 12/100 [00:07<01:00,  1.45it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  18%|█▊        | 90/500 [00:00<00:00, 896.31it/s]
# Epoch Progress:  36%|███▌      | 180/500 [00:00<00:00, 878.61it/s]
# Epoch Progress:  54%|█████▍    | 269/500 [00:00<00:00, 882.65it/s]
# Epoch Progress:  72%|███████▏  | 360/500 [00:00<00:00, 890.18it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 763.00it/s]
# Experiment Progress:  13%|█▎        | 13/100 [00:08<00:59,  1.46it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  18%|█▊        | 90/500 [00:00<00:00, 894.92it/s]
# Epoch Progress:  37%|███▋      | 185/500 [00:00<00:00, 926.62it/s]
# Epoch Progress:  56%|█████▌    | 278/500 [00:00<00:00, 916.97it/s]
# Epoch Progress:  75%|███████▍  | 373/500 [00:00<00:00, 929.16it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 811.69it/s]
# Experiment Progress:  14%|█▍        | 14/100 [00:08<00:57,  1.50it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  20%|██        | 101/500 [00:00<00:00, 1009.59it/s]
# Epoch Progress:  40%|████      | 202/500 [00:00<00:00, 996.57it/s]
# Epoch Progress:  60%|██████    | 302/500 [00:00<00:00, 973.01it/s]
# Epoch Progress:  80%|████████  | 400/500 [00:00<00:00, 957.35it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 834.08it/s]
# Experiment Progress:  15%|█▌        | 15/100 [00:09<01:04,  1.32it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  20%|██        | 100/500 [00:00<00:00, 994.66it/s]
# Epoch Progress:  40%|████      | 200/500 [00:00<00:00, 991.72it/s]
# Epoch Progress:  60%|██████    | 300/500 [00:00<00:00, 978.75it/s]
# Epoch Progress:  80%|███████▉  | 398/500 [00:00<00:00, 962.67it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 818.41it/s]
# Experiment Progress:  16%|█▌        | 16/100 [00:10<01:00,  1.39it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  19%|█▉        | 97/500 [00:00<00:00, 969.01it/s]
# Epoch Progress:  39%|███▉      | 194/500 [00:00<00:00, 966.78it/s]
# Epoch Progress:  58%|█████▊    | 291/500 [00:00<00:00, 955.80it/s]
# Epoch Progress:  77%|███████▋  | 387/500 [00:00<00:00, 947.03it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 822.30it/s]
# Experiment Progress:  17%|█▋        | 17/100 [00:11<00:57,  1.45it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  20%|█▉        | 98/500 [00:00<00:00, 975.83it/s]
# Epoch Progress:  40%|███▉      | 198/500 [00:00<00:00, 984.31it/s]
# Epoch Progress:  60%|██████    | 300/500 [00:00<00:00, 997.21it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 862.81it/s]
# Experiment Progress:  18%|█▊        | 18/100 [00:11<00:54,  1.51it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  20%|██        | 101/500 [00:00<00:00, 1004.09it/s]
# Epoch Progress:  40%|████      | 202/500 [00:00<00:00, 1000.75it/s]
# Epoch Progress:  61%|██████    | 303/500 [00:00<00:00, 991.28it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 838.29it/s]
# Experiment Progress:  19%|█▉        | 19/100 [00:12<00:52,  1.55it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  19%|█▉        | 97/500 [00:00<00:00, 969.75it/s]
# Epoch Progress:  39%|███▉      | 194/500 [00:00<00:00, 934.91it/s]
# Epoch Progress:  58%|█████▊    | 288/500 [00:00<00:00, 925.95it/s]
# Epoch Progress:  76%|███████▌  | 381/500 [00:00<00:00, 922.07it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 801.96it/s]
# Experiment Progress:  20%|██        | 20/100 [00:13<00:59,  1.33it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  19%|█▉        | 97/500 [00:00<00:00, 963.76it/s]
# Epoch Progress:  41%|████      | 203/500 [00:00<00:00, 1019.47it/s]
# Epoch Progress:  61%|██████    | 305/500 [00:00<00:00, 1005.49it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 862.16it/s]
# Experiment Progress:  21%|██        | 21/100 [00:13<00:55,  1.42it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  19%|█▉        | 94/500 [00:00<00:00, 935.65it/s]
# Epoch Progress:  38%|███▊      | 191/500 [00:00<00:00, 952.02it/s]
# Epoch Progress:  59%|█████▊    | 293/500 [00:00<00:00, 979.45it/s]
# Epoch Progress:  78%|███████▊  | 391/500 [00:00<00:00, 954.95it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 810.27it/s]
# Experiment Progress:  22%|██▏       | 22/100 [00:14<00:53,  1.47it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  19%|█▊        | 93/500 [00:00<00:00, 924.62it/s]
# Epoch Progress:  37%|███▋      | 186/500 [00:00<00:00, 926.78it/s]
# Epoch Progress:  56%|█████▌    | 279/500 [00:00<00:00, 922.82it/s]
# Epoch Progress:  74%|███████▍  | 372/500 [00:00<00:00, 918.92it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 794.49it/s]
# Experiment Progress:  23%|██▎       | 23/100 [00:15<00:51,  1.49it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  19%|█▉        | 97/500 [00:00<00:00, 965.48it/s]
# Epoch Progress:  39%|███▉      | 194/500 [00:00<00:00, 961.67it/s]
# Epoch Progress:  59%|█████▉    | 294/500 [00:00<00:00, 977.62it/s]
# Epoch Progress:  78%|███████▊  | 392/500 [00:00<00:00, 978.30it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 839.63it/s]
# Experiment Progress:  24%|██▍       | 24/100 [00:15<00:49,  1.53it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  19%|█▉        | 96/500 [00:00<00:00, 951.61it/s]
# Epoch Progress:  38%|███▊      | 192/500 [00:00<00:00, 948.64it/s]
# Epoch Progress:  58%|█████▊    | 290/500 [00:00<00:00, 958.98it/s]
# Epoch Progress:  77%|███████▋  | 386/500 [00:00<00:00, 956.25it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 807.91it/s]
# Experiment Progress:  25%|██▌       | 25/100 [00:16<00:56,  1.33it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  19%|█▊        | 93/500 [00:00<00:00, 927.13it/s]
# Epoch Progress:  38%|███▊      | 188/500 [00:00<00:00, 937.96it/s]
# Epoch Progress:  56%|█████▋    | 282/500 [00:00<00:00, 933.85it/s]
# Epoch Progress:  75%|███████▌  | 376/500 [00:00<00:00, 931.33it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 804.35it/s]
# Experiment Progress:  26%|██▌       | 26/100 [00:17<00:53,  1.39it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  18%|█▊        | 92/500 [00:00<00:00, 912.90it/s]
# Epoch Progress:  37%|███▋      | 184/500 [00:00<00:00, 906.38it/s]
# Epoch Progress:  55%|█████▌    | 276/500 [00:00<00:00, 911.74it/s]
# Epoch Progress:  74%|███████▎  | 368/500 [00:00<00:00, 910.61it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 765.91it/s]
# Experiment Progress:  27%|██▋       | 27/100 [00:18<00:51,  1.42it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  18%|█▊        | 90/500 [00:00<00:00, 893.71it/s]
# Epoch Progress:  36%|███▌      | 181/500 [00:00<00:00, 900.47it/s]
# Epoch Progress:  55%|█████▍    | 274/500 [00:00<00:00, 910.44it/s]
# Epoch Progress:  74%|███████▍  | 371/500 [00:00<00:00, 933.23it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 793.43it/s]
# Experiment Progress:  28%|██▊       | 28/100 [00:18<00:49,  1.46it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  16%|█▌        | 81/500 [00:00<00:00, 808.39it/s]
# Epoch Progress:  34%|███▍      | 169/500 [00:00<00:00, 850.31it/s]
# Epoch Progress:  53%|█████▎    | 263/500 [00:00<00:00, 886.20it/s]
# Epoch Progress:  70%|███████   | 352/500 [00:00<00:00, 879.84it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 755.98it/s]
# Experiment Progress:  29%|██▉       | 29/100 [00:19<00:48,  1.46it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  18%|█▊        | 92/500 [00:00<00:00, 917.51it/s]
# Epoch Progress:  37%|███▋      | 184/500 [00:00<00:00, 910.78it/s]
# Epoch Progress:  55%|█████▌    | 276/500 [00:00<00:00, 911.54it/s]
# Epoch Progress:  74%|███████▎  | 368/500 [00:00<00:00, 897.78it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 770.48it/s]
# Experiment Progress:  30%|███       | 30/100 [00:20<00:55,  1.26it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  16%|█▌        | 80/500 [00:00<00:00, 798.86it/s]
# Epoch Progress:  34%|███▍      | 171/500 [00:00<00:00, 861.06it/s]
# Epoch Progress:  52%|█████▏    | 260/500 [00:00<00:00, 871.56it/s]
# Epoch Progress:  70%|██████▉   | 348/500 [00:00<00:00, 835.56it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 732.29it/s]
# Experiment Progress:  31%|███       | 31/100 [00:21<00:52,  1.31it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  18%|█▊        | 90/500 [00:00<00:00, 896.53it/s]
# Epoch Progress:  37%|███▋      | 185/500 [00:00<00:00, 924.65it/s]
# Epoch Progress:  56%|█████▌    | 278/500 [00:00<00:00, 891.69it/s]
# Epoch Progress:  74%|███████▎  | 368/500 [00:00<00:00, 891.21it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 772.96it/s]
# Experiment Progress:  32%|███▏      | 32/100 [00:21<00:49,  1.36it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  16%|█▌        | 79/500 [00:00<00:00, 784.06it/s]
# Epoch Progress:  32%|███▏      | 158/500 [00:00<00:00, 743.62it/s]
# Epoch Progress:  47%|████▋     | 233/500 [00:00<00:00, 734.71it/s]
# Epoch Progress:  63%|██████▎   | 317/500 [00:00<00:00, 774.15it/s]
# Epoch Progress:  79%|███████▉  | 395/500 [00:00<00:00, 747.50it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 685.18it/s]
# Experiment Progress:  33%|███▎      | 33/100 [00:22<00:49,  1.36it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  19%|█▊        | 93/500 [00:00<00:00, 927.08it/s]
# Epoch Progress:  38%|███▊      | 188/500 [00:00<00:00, 940.01it/s]
# Epoch Progress:  57%|█████▋    | 283/500 [00:00<00:00, 928.78it/s]
# Epoch Progress:  76%|███████▌  | 380/500 [00:00<00:00, 942.58it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 807.61it/s]
# Experiment Progress:  34%|███▍      | 34/100 [00:23<00:46,  1.42it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  20%|██        | 101/500 [00:00<00:00, 1003.30it/s]
# Epoch Progress:  40%|████      | 202/500 [00:00<00:00, 990.51it/s]
# Epoch Progress:  60%|██████    | 302/500 [00:00<00:00, 988.26it/s]
# Epoch Progress:  80%|████████  | 401/500 [00:00<00:00, 976.58it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 825.88it/s]
# Experiment Progress:  35%|███▌      | 35/100 [00:24<00:51,  1.27it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  20%|█▉        | 99/500 [00:00<00:00, 989.23it/s]
# Epoch Progress:  40%|███▉      | 198/500 [00:00<00:00, 978.80it/s]
# Epoch Progress:  59%|█████▉    | 296/500 [00:00<00:00, 971.13it/s]
# Epoch Progress:  79%|███████▉  | 394/500 [00:00<00:00, 964.74it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 822.93it/s]
# Experiment Progress:  36%|███▌      | 36/100 [00:24<00:47,  1.36it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  20%|█▉        | 98/500 [00:00<00:00, 970.25it/s]
# Epoch Progress:  39%|███▉      | 196/500 [00:00<00:00, 964.94it/s]
# Epoch Progress:  59%|█████▊    | 293/500 [00:00<00:00, 947.33it/s]
# Epoch Progress:  78%|███████▊  | 388/500 [00:00<00:00, 931.45it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 803.95it/s]
# Experiment Progress:  37%|███▋      | 37/100 [00:25<00:44,  1.41it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  20%|█▉        | 98/500 [00:00<00:00, 972.17it/s]
# Epoch Progress:  39%|███▉      | 196/500 [00:00<00:00, 969.58it/s]
# Epoch Progress:  59%|█████▉    | 294/500 [00:00<00:00, 970.63it/s]
# Epoch Progress:  79%|███████▉  | 394/500 [00:00<00:00, 979.71it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 834.75it/s]
# Experiment Progress:  38%|███▊      | 38/100 [00:26<00:42,  1.47it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  20%|██        | 100/500 [00:00<00:00, 994.84it/s]
# Epoch Progress:  40%|████      | 200/500 [00:00<00:00, 995.91it/s]
# Epoch Progress:  60%|██████    | 300/500 [00:00<00:00, 985.28it/s]
# Epoch Progress:  80%|███████▉  | 399/500 [00:00<00:00, 966.09it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 826.12it/s]
# Experiment Progress:  39%|███▉      | 39/100 [00:26<00:40,  1.51it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  19%|█▉        | 95/500 [00:00<00:00, 947.07it/s]
# Epoch Progress:  38%|███▊      | 191/500 [00:00<00:00, 950.90it/s]
# Epoch Progress:  57%|█████▋    | 287/500 [00:00<00:00, 950.31it/s]
# Epoch Progress:  77%|███████▋  | 383/500 [00:00<00:00, 942.80it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 814.31it/s]
# Experiment Progress:  40%|████      | 40/100 [00:27<00:45,  1.32it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  20%|██        | 100/500 [00:00<00:00, 996.17it/s]
# Epoch Progress:  40%|████      | 200/500 [00:00<00:00, 981.34it/s]
# Epoch Progress:  60%|█████▉    | 299/500 [00:00<00:00, 983.94it/s]
# Epoch Progress:  80%|███████▉  | 399/500 [00:00<00:00, 986.51it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 837.54it/s]
# Experiment Progress:  41%|████      | 41/100 [00:28<00:42,  1.40it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  20%|█▉        | 98/500 [00:00<00:00, 977.49it/s]
# Epoch Progress:  39%|███▉      | 196/500 [00:00<00:00, 964.91it/s]
# Epoch Progress:  59%|█████▊    | 293/500 [00:00<00:00, 960.85it/s]
# Epoch Progress:  78%|███████▊  | 390/500 [00:00<00:00, 957.99it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 820.97it/s]
# Experiment Progress:  42%|████▏     | 42/100 [00:28<00:39,  1.45it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  19%|█▉        | 96/500 [00:00<00:00, 958.44it/s]
# Epoch Progress:  39%|███▉      | 194/500 [00:00<00:00, 967.38it/s]
# Epoch Progress:  58%|█████▊    | 291/500 [00:00<00:00, 960.87it/s]
# Epoch Progress:  78%|███████▊  | 388/500 [00:00<00:00, 959.70it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 831.16it/s]
# Experiment Progress:  43%|████▎     | 43/100 [00:29<00:37,  1.50it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  20%|█▉        | 99/500 [00:00<00:00, 982.08it/s]
# Epoch Progress:  40%|███▉      | 199/500 [00:00<00:00, 992.47it/s]
# Epoch Progress:  60%|█████▉    | 299/500 [00:00<00:00, 987.83it/s]
# Epoch Progress:  80%|███████▉  | 398/500 [00:00<00:00, 966.24it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 833.62it/s]
# Experiment Progress:  44%|████▍     | 44/100 [00:30<00:36,  1.53it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  20%|██        | 101/500 [00:00<00:00, 1001.75it/s]
# Epoch Progress:  40%|████      | 202/500 [00:00<00:00, 970.33it/s]
# Epoch Progress:  60%|██████    | 300/500 [00:00<00:00, 942.87it/s]
# Epoch Progress:  79%|███████▉  | 396/500 [00:00<00:00, 946.65it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 815.64it/s]
# Experiment Progress:  45%|████▌     | 45/100 [00:31<00:41,  1.32it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  19%|█▉        | 94/500 [00:00<00:00, 937.59it/s]
# Epoch Progress:  38%|███▊      | 188/500 [00:00<00:00, 935.07it/s]
# Epoch Progress:  57%|█████▋    | 286/500 [00:00<00:00, 953.24it/s]
# Epoch Progress:  78%|███████▊  | 388/500 [00:00<00:00, 976.84it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 823.28it/s]
# Experiment Progress:  46%|████▌     | 46/100 [00:31<00:38,  1.40it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  20%|█▉        | 99/500 [00:00<00:00, 985.91it/s]
# Epoch Progress:  40%|███▉      | 198/500 [00:00<00:00, 965.20it/s]
# Epoch Progress:  59%|█████▉    | 295/500 [00:00<00:00, 952.88it/s]
# Epoch Progress:  78%|███████▊  | 391/500 [00:00<00:00, 939.29it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 809.20it/s]
# Experiment Progress:  47%|████▋     | 47/100 [00:32<00:36,  1.45it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  19%|█▊        | 93/500 [00:00<00:00, 928.20it/s]
# Epoch Progress:  38%|███▊      | 190/500 [00:00<00:00, 950.97it/s]
# Epoch Progress:  57%|█████▋    | 286/500 [00:00<00:00, 935.99it/s]
# Epoch Progress:  76%|███████▌  | 380/500 [00:00<00:00, 917.49it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 799.60it/s]
# Experiment Progress:  48%|████▊     | 48/100 [00:33<00:35,  1.48it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  18%|█▊        | 92/500 [00:00<00:00, 918.93it/s]
# Epoch Progress:  37%|███▋      | 185/500 [00:00<00:00, 921.93it/s]
# Epoch Progress:  56%|█████▌    | 278/500 [00:00<00:00, 925.60it/s]
# Epoch Progress:  74%|███████▍  | 371/500 [00:00<00:00, 923.46it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 784.25it/s]
# Experiment Progress:  49%|████▉     | 49/100 [00:33<00:34,  1.49it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  19%|█▉        | 94/500 [00:00<00:00, 934.14it/s]
# Epoch Progress:  38%|███▊      | 189/500 [00:00<00:00, 938.82it/s]
# Epoch Progress:  57%|█████▋    | 284/500 [00:00<00:00, 942.66it/s]
# Epoch Progress:  76%|███████▌  | 381/500 [00:00<00:00, 949.12it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 817.11it/s]
# Experiment Progress:  50%|█████     | 50/100 [00:34<00:38,  1.29it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  18%|█▊        | 90/500 [00:00<00:00, 894.24it/s]
# Epoch Progress:  37%|███▋      | 184/500 [00:00<00:00, 914.87it/s]
# Epoch Progress:  56%|█████▌    | 280/500 [00:00<00:00, 934.13it/s]
# Epoch Progress:  75%|███████▍  | 374/500 [00:00<00:00, 933.22it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 796.47it/s]
# Experiment Progress:  51%|█████     | 51/100 [00:35<00:35,  1.36it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  19%|█▉        | 96/500 [00:00<00:00, 950.82it/s]
# Epoch Progress:  38%|███▊      | 192/500 [00:00<00:00, 944.42it/s]
# Epoch Progress:  57%|█████▋    | 287/500 [00:00<00:00, 922.06it/s]
# Epoch Progress:  76%|███████▌  | 380/500 [00:00<00:00, 916.60it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 803.22it/s]
# Experiment Progress:  52%|█████▏    | 52/100 [00:36<00:33,  1.42it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  18%|█▊        | 90/500 [00:00<00:00, 894.13it/s]
# Epoch Progress:  37%|███▋      | 185/500 [00:00<00:00, 925.14it/s]
# Epoch Progress:  56%|█████▌    | 281/500 [00:00<00:00, 940.59it/s]
# Epoch Progress:  75%|███████▌  | 376/500 [00:00<00:00, 939.60it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 806.62it/s]
# Experiment Progress:  53%|█████▎    | 53/100 [00:36<00:32,  1.46it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  19%|█▉        | 95/500 [00:00<00:00, 949.35it/s]
# Epoch Progress:  38%|███▊      | 190/500 [00:00<00:00, 940.92it/s]
# Epoch Progress:  57%|█████▋    | 287/500 [00:00<00:00, 950.44it/s]
# Epoch Progress:  77%|███████▋  | 384/500 [00:00<00:00, 955.49it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 807.98it/s]
# Experiment Progress:  54%|█████▍    | 54/100 [00:37<00:30,  1.49it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  17%|█▋        | 84/500 [00:00<00:00, 834.56it/s]
# Epoch Progress:  36%|███▌      | 179/500 [00:00<00:00, 898.35it/s]
# Epoch Progress:  55%|█████▍    | 274/500 [00:00<00:00, 917.87it/s]
# Epoch Progress:  73%|███████▎  | 367/500 [00:00<00:00, 922.59it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 793.78it/s]
# Experiment Progress:  55%|█████▌    | 55/100 [00:38<00:35,  1.28it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  18%|█▊        | 91/500 [00:00<00:00, 908.39it/s]
# Epoch Progress:  36%|███▋      | 182/500 [00:00<00:00, 886.99it/s]
# Epoch Progress:  54%|█████▍    | 271/500 [00:00<00:00, 841.71it/s]
# Epoch Progress:  71%|███████   | 356/500 [00:00<00:00, 824.87it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 740.25it/s]
# Experiment Progress:  56%|█████▌    | 56/100 [00:39<00:33,  1.33it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  19%|█▉        | 95/500 [00:00<00:00, 943.52it/s]
# Epoch Progress:  38%|███▊      | 190/500 [00:00<00:00, 945.85it/s]
# Epoch Progress:  57%|█████▋    | 286/500 [00:00<00:00, 948.71it/s]
# Epoch Progress:  76%|███████▌  | 381/500 [00:00<00:00, 948.82it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 811.78it/s]
# Experiment Progress:  57%|█████▋    | 57/100 [00:39<00:30,  1.39it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  19%|█▉        | 95/500 [00:00<00:00, 942.38it/s]
# Epoch Progress:  38%|███▊      | 190/500 [00:00<00:00, 944.31it/s]
# Epoch Progress:  57%|█████▋    | 287/500 [00:00<00:00, 954.59it/s]
# Epoch Progress:  77%|███████▋  | 383/500 [00:00<00:00, 956.21it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 815.58it/s]
# Experiment Progress:  58%|█████▊    | 58/100 [00:40<00:29,  1.45it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  19%|█▊        | 93/500 [00:00<00:00, 926.76it/s]
# Epoch Progress:  37%|███▋      | 186/500 [00:00<00:00, 924.96it/s]
# Epoch Progress:  56%|█████▌    | 279/500 [00:00<00:00, 913.71it/s]
# Epoch Progress:  74%|███████▍  | 371/500 [00:00<00:00, 899.39it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 779.12it/s]
# Experiment Progress:  59%|█████▉    | 59/100 [00:40<00:27,  1.47it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  19%|█▉        | 96/500 [00:00<00:00, 951.64it/s]
# Epoch Progress:  39%|███▊      | 193/500 [00:00<00:00, 958.16it/s]
# Epoch Progress:  58%|█████▊    | 289/500 [00:00<00:00, 903.16it/s]
# Epoch Progress:  76%|███████▌  | 380/500 [00:00<00:00, 883.63it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 780.27it/s]
# Experiment Progress:  60%|██████    | 60/100 [00:42<00:31,  1.27it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  19%|█▉        | 96/500 [00:00<00:00, 951.80it/s]
# Epoch Progress:  39%|███▉      | 194/500 [00:00<00:00, 963.73it/s]
# Epoch Progress:  58%|█████▊    | 291/500 [00:00<00:00, 890.27it/s]
# Epoch Progress:  76%|███████▌  | 381/500 [00:00<00:00, 885.87it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 780.99it/s]
# Experiment Progress:  61%|██████    | 61/100 [00:42<00:29,  1.33it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  19%|█▉        | 95/500 [00:00<00:00, 946.96it/s]
# Epoch Progress:  38%|███▊      | 190/500 [00:00<00:00, 934.40it/s]
# Epoch Progress:  57%|█████▋    | 284/500 [00:00<00:00, 900.05it/s]
# Epoch Progress:  75%|███████▌  | 375/500 [00:00<00:00, 882.75it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 767.09it/s]
# Experiment Progress:  62%|██████▏   | 62/100 [00:43<00:27,  1.38it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  18%|█▊        | 88/500 [00:00<00:00, 878.24it/s]
# Epoch Progress:  35%|███▌      | 176/500 [00:00<00:00, 876.51it/s]
# Epoch Progress:  53%|█████▎    | 266/500 [00:00<00:00, 883.17it/s]
# Epoch Progress:  71%|███████   | 355/500 [00:00<00:00, 881.81it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 768.45it/s]
# Experiment Progress:  63%|██████▎   | 63/100 [00:44<00:26,  1.41it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  16%|█▌        | 81/500 [00:00<00:00, 805.68it/s]
# Epoch Progress:  34%|███▍      | 169/500 [00:00<00:00, 847.43it/s]
# Epoch Progress:  51%|█████     | 256/500 [00:00<00:00, 854.15it/s]
# Epoch Progress:  68%|██████▊   | 342/500 [00:00<00:00, 851.89it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 754.06it/s]
# Experiment Progress:  64%|██████▍   | 64/100 [00:44<00:25,  1.43it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  18%|█▊        | 90/500 [00:00<00:00, 896.63it/s]
# Epoch Progress:  36%|███▌      | 180/500 [00:00<00:00, 878.35it/s]
# Epoch Progress:  54%|█████▎    | 268/500 [00:00<00:00, 872.86it/s]
# Epoch Progress:  71%|███████   | 356/500 [00:00<00:00, 868.70it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 747.81it/s]
# Experiment Progress:  65%|██████▌   | 65/100 [00:45<00:28,  1.21it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  18%|█▊        | 91/500 [00:00<00:00, 906.47it/s]
# Epoch Progress:  37%|███▋      | 184/500 [00:00<00:00, 918.19it/s]
# Epoch Progress:  55%|█████▌    | 277/500 [00:00<00:00, 923.29it/s]
# Epoch Progress:  74%|███████▍  | 370/500 [00:00<00:00, 919.06it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 773.74it/s]
# Experiment Progress:  66%|██████▌   | 66/100 [00:46<00:26,  1.29it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  18%|█▊        | 90/500 [00:00<00:00, 897.16it/s]
# Epoch Progress:  36%|███▌      | 180/500 [00:00<00:00, 885.56it/s]
# Epoch Progress:  54%|█████▍    | 269/500 [00:00<00:00, 865.83it/s]
# Epoch Progress:  72%|███████▏  | 359/500 [00:00<00:00, 876.52it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 757.61it/s]
# Experiment Progress:  67%|██████▋   | 67/100 [00:47<00:24,  1.34it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  18%|█▊        | 90/500 [00:00<00:00, 890.67it/s]
# Epoch Progress:  36%|███▌      | 181/500 [00:00<00:00, 897.21it/s]
# Epoch Progress:  54%|█████▍    | 271/500 [00:00<00:00, 879.61it/s]
# Epoch Progress:  72%|███████▏  | 360/500 [00:00<00:00, 880.00it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 758.64it/s]
# Experiment Progress:  68%|██████▊   | 68/100 [00:47<00:23,  1.38it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  18%|█▊        | 88/500 [00:00<00:00, 872.83it/s]
# Epoch Progress:  36%|███▌      | 179/500 [00:00<00:00, 889.52it/s]
# Epoch Progress:  54%|█████▍    | 269/500 [00:00<00:00, 890.51it/s]
# Epoch Progress:  72%|███████▏  | 359/500 [00:00<00:00, 876.24it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 756.35it/s]
# Experiment Progress:  69%|██████▉   | 69/100 [00:48<00:22,  1.41it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  18%|█▊        | 89/500 [00:00<00:00, 887.25it/s]
# Epoch Progress:  36%|███▌      | 180/500 [00:00<00:00, 898.10it/s]
# Epoch Progress:  54%|█████▍    | 270/500 [00:00<00:00, 898.40it/s]
# Epoch Progress:  72%|███████▏  | 360/500 [00:00<00:00, 896.98it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 774.62it/s]
# Experiment Progress:  70%|███████   | 70/100 [00:49<00:24,  1.24it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  18%|█▊        | 91/500 [00:00<00:00, 903.88it/s]
# Epoch Progress:  36%|███▋      | 182/500 [00:00<00:00, 885.35it/s]
# Epoch Progress:  54%|█████▍    | 271/500 [00:00<00:00, 870.35it/s]
# Epoch Progress:  72%|███████▏  | 359/500 [00:00<00:00, 866.41it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 754.68it/s]
# Experiment Progress:  71%|███████   | 71/100 [00:50<00:22,  1.30it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  17%|█▋        | 87/500 [00:00<00:00, 864.04it/s]
# Epoch Progress:  35%|███▍      | 174/500 [00:00<00:00, 864.08it/s]
# Epoch Progress:  52%|█████▏    | 262/500 [00:00<00:00, 871.02it/s]
# Epoch Progress:  70%|███████   | 350/500 [00:00<00:00, 871.90it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 757.12it/s]
# Experiment Progress:  72%|███████▏  | 72/100 [00:50<00:20,  1.35it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  18%|█▊        | 91/500 [00:00<00:00, 900.86it/s]
# Epoch Progress:  36%|███▋      | 182/500 [00:00<00:00, 890.30it/s]
# Epoch Progress:  54%|█████▍    | 272/500 [00:00<00:00, 889.02it/s]
# Epoch Progress:  72%|███████▏  | 361/500 [00:00<00:00, 873.16it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 765.07it/s]
# Experiment Progress:  73%|███████▎  | 73/100 [00:51<00:19,  1.39it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  18%|█▊        | 89/500 [00:00<00:00, 883.99it/s]
# Epoch Progress:  36%|███▌      | 178/500 [00:00<00:00, 882.71it/s]
# Epoch Progress:  53%|█████▎    | 267/500 [00:00<00:00, 880.67it/s]
# Epoch Progress:  71%|███████   | 356/500 [00:00<00:00, 875.63it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 761.29it/s]
# Experiment Progress:  74%|███████▍  | 74/100 [00:52<00:18,  1.42it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  18%|█▊        | 89/500 [00:00<00:00, 888.05it/s]
# Epoch Progress:  36%|███▌      | 178/500 [00:00<00:00, 876.64it/s]
# Epoch Progress:  53%|█████▎    | 266/500 [00:00<00:00, 862.30it/s]
# Epoch Progress:  71%|███████   | 353/500 [00:00<00:00, 859.57it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 747.83it/s]
# Experiment Progress:  75%|███████▌  | 75/100 [00:53<00:20,  1.23it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  17%|█▋        | 85/500 [00:00<00:00, 845.33it/s]
# Epoch Progress:  35%|███▍      | 174/500 [00:00<00:00, 870.80it/s]
# Epoch Progress:  53%|█████▎    | 263/500 [00:00<00:00, 877.14it/s]
# Epoch Progress:  71%|███████   | 356/500 [00:00<00:00, 895.68it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 761.99it/s]
# Experiment Progress:  76%|███████▌  | 76/100 [00:53<00:18,  1.30it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  16%|█▌        | 79/500 [00:00<00:00, 786.38it/s]
# Epoch Progress:  32%|███▏      | 161/500 [00:00<00:00, 803.27it/s]
# Epoch Progress:  50%|████▉     | 249/500 [00:00<00:00, 837.92it/s]
# Epoch Progress:  68%|██████▊   | 339/500 [00:00<00:00, 861.08it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 743.00it/s]
# Experiment Progress:  77%|███████▋  | 77/100 [00:54<00:17,  1.34it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  17%|█▋        | 87/500 [00:00<00:00, 868.35it/s]
# Epoch Progress:  35%|███▌      | 177/500 [00:00<00:00, 882.74it/s]
# Epoch Progress:  53%|█████▎    | 267/500 [00:00<00:00, 886.87it/s]
# Epoch Progress:  71%|███████▏  | 357/500 [00:00<00:00, 891.41it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 765.86it/s]
# Experiment Progress:  78%|███████▊  | 78/100 [00:55<00:15,  1.38it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  17%|█▋        | 87/500 [00:00<00:00, 865.02it/s]
# Epoch Progress:  35%|███▌      | 175/500 [00:00<00:00, 872.45it/s]
# Epoch Progress:  53%|█████▎    | 263/500 [00:00<00:00, 874.34it/s]
# Epoch Progress:  70%|███████   | 352/500 [00:00<00:00, 879.31it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 750.82it/s]
# Experiment Progress:  79%|███████▉  | 79/100 [00:56<00:14,  1.41it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  17%|█▋        | 87/500 [00:00<00:00, 862.56it/s]
# Epoch Progress:  35%|███▌      | 177/500 [00:00<00:00, 883.42it/s]
# Epoch Progress:  53%|█████▎    | 267/500 [00:00<00:00, 889.01it/s]
# Epoch Progress:  72%|███████▏  | 361/500 [00:00<00:00, 906.98it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 779.76it/s]
# Experiment Progress:  80%|████████  | 80/100 [00:57<00:16,  1.23it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  18%|█▊        | 89/500 [00:00<00:00, 886.48it/s]
# Epoch Progress:  36%|███▌      | 179/500 [00:00<00:00, 891.43it/s]
# Epoch Progress:  54%|█████▍    | 269/500 [00:00<00:00, 889.53it/s]
# Epoch Progress:  72%|███████▏  | 359/500 [00:00<00:00, 892.28it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 769.42it/s]
# Experiment Progress:  81%|████████  | 81/100 [00:57<00:14,  1.30it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  18%|█▊        | 88/500 [00:00<00:00, 871.86it/s]
# Epoch Progress:  36%|███▌      | 178/500 [00:00<00:00, 884.34it/s]
# Epoch Progress:  54%|█████▍    | 271/500 [00:00<00:00, 902.89it/s]
# Epoch Progress:  72%|███████▏  | 362/500 [00:00<00:00, 899.93it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 773.15it/s]
# Experiment Progress:  82%|████████▏ | 82/100 [00:58<00:13,  1.36it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  18%|█▊        | 88/500 [00:00<00:00, 878.66it/s]
# Epoch Progress:  35%|███▌      | 176/500 [00:00<00:00, 859.22it/s]
# Epoch Progress:  53%|█████▎    | 263/500 [00:00<00:00, 860.73it/s]
# Epoch Progress:  71%|███████   | 353/500 [00:00<00:00, 875.74it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 749.03it/s]
# Experiment Progress:  83%|████████▎ | 83/100 [00:59<00:12,  1.39it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  18%|█▊        | 91/500 [00:00<00:00, 906.09it/s]
# Epoch Progress:  36%|███▋      | 182/500 [00:00<00:00, 901.51it/s]
# Epoch Progress:  55%|█████▍    | 273/500 [00:00<00:00, 892.65it/s]
# Epoch Progress:  73%|███████▎  | 363/500 [00:00<00:00, 883.74it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 757.93it/s]
# Experiment Progress:  84%|████████▍ | 84/100 [00:59<00:11,  1.42it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  18%|█▊        | 89/500 [00:00<00:00, 884.32it/s]
# Epoch Progress:  36%|███▌      | 179/500 [00:00<00:00, 893.46it/s]
# Epoch Progress:  54%|█████▍    | 269/500 [00:00<00:00, 891.51it/s]
# Epoch Progress:  72%|███████▏  | 359/500 [00:00<00:00, 884.68it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 762.56it/s]
# Experiment Progress:  85%|████████▌ | 85/100 [01:00<00:12,  1.23it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  18%|█▊        | 91/500 [00:00<00:00, 905.63it/s]
# Epoch Progress:  36%|███▋      | 182/500 [00:00<00:00, 896.86it/s]
# Epoch Progress:  54%|█████▍    | 272/500 [00:00<00:00, 875.91it/s]
# Epoch Progress:  72%|███████▏  | 360/500 [00:00<00:00, 838.16it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 734.38it/s]
# Experiment Progress:  86%|████████▌ | 86/100 [01:01<00:10,  1.29it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  17%|█▋        | 86/500 [00:00<00:00, 849.67it/s]
# Epoch Progress:  34%|███▍      | 171/500 [00:00<00:00, 838.72it/s]
# Epoch Progress:  51%|█████     | 256/500 [00:00<00:00, 841.90it/s]
# Epoch Progress:  68%|██████▊   | 341/500 [00:00<00:00, 840.92it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 732.01it/s]
# Experiment Progress:  87%|████████▋ | 87/100 [01:02<00:09,  1.33it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  18%|█▊        | 91/500 [00:00<00:00, 900.56it/s]
# Epoch Progress:  36%|███▋      | 182/500 [00:00<00:00, 888.64it/s]
# Epoch Progress:  54%|█████▍    | 272/500 [00:00<00:00, 890.27it/s]
# Epoch Progress:  72%|███████▏  | 362/500 [00:00<00:00, 874.59it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 750.21it/s]
# Experiment Progress:  88%|████████▊ | 88/100 [01:02<00:08,  1.37it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  18%|█▊        | 91/500 [00:00<00:00, 903.75it/s]
# Epoch Progress:  36%|███▋      | 182/500 [00:00<00:00, 900.35it/s]
# Epoch Progress:  55%|█████▍    | 273/500 [00:00<00:00, 901.25it/s]
# Epoch Progress:  73%|███████▎  | 364/500 [00:00<00:00, 884.80it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 756.31it/s]
# Experiment Progress:  89%|████████▉ | 89/100 [01:03<00:07,  1.40it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  16%|█▌        | 81/500 [00:00<00:00, 801.93it/s]
# Epoch Progress:  33%|███▎      | 165/500 [00:00<00:00, 820.32it/s]
# Epoch Progress:  50%|█████     | 251/500 [00:00<00:00, 835.75it/s]
# Epoch Progress:  67%|██████▋   | 336/500 [00:00<00:00, 839.87it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 731.10it/s]
# Experiment Progress:  90%|█████████ | 90/100 [01:04<00:08,  1.21it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  17%|█▋        | 87/500 [00:00<00:00, 868.48it/s]
# Epoch Progress:  35%|███▌      | 175/500 [00:00<00:00, 870.16it/s]
# Epoch Progress:  53%|█████▎    | 263/500 [00:00<00:00, 854.81it/s]
# Epoch Progress:  70%|██████▉   | 349/500 [00:00<00:00, 852.50it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 740.86it/s]
# Experiment Progress:  91%|█████████ | 91/100 [01:05<00:07,  1.27it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  18%|█▊        | 90/500 [00:00<00:00, 896.85it/s]
# Epoch Progress:  36%|███▌      | 180/500 [00:00<00:00, 877.51it/s]
# Epoch Progress:  54%|█████▎    | 268/500 [00:00<00:00, 857.59it/s]
# Epoch Progress:  71%|███████   | 354/500 [00:00<00:00, 850.07it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 728.40it/s]
# Experiment Progress:  92%|█████████▏| 92/100 [01:06<00:06,  1.32it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  18%|█▊        | 89/500 [00:00<00:00, 889.18it/s]
# Epoch Progress:  36%|███▌      | 178/500 [00:00<00:00, 876.87it/s]
# Epoch Progress:  53%|█████▎    | 266/500 [00:00<00:00, 828.38it/s]
# Epoch Progress:  70%|███████   | 350/500 [00:00<00:00, 832.01it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 727.62it/s]
# Experiment Progress:  93%|█████████▎| 93/100 [01:06<00:05,  1.35it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  17%|█▋        | 86/500 [00:00<00:00, 854.91it/s]
# Epoch Progress:  34%|███▍      | 172/500 [00:00<00:00, 824.54it/s]
# Epoch Progress:  51%|█████     | 255/500 [00:00<00:00, 817.37it/s]
# Epoch Progress:  67%|██████▋   | 337/500 [00:00<00:00, 811.35it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 720.49it/s]
# Experiment Progress:  94%|█████████▍| 94/100 [01:07<00:04,  1.36it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  16%|█▌        | 78/500 [00:00<00:00, 773.96it/s]
# Epoch Progress:  32%|███▏      | 162/500 [00:00<00:00, 809.30it/s]
# Epoch Progress:  49%|████▉     | 245/500 [00:00<00:00, 818.59it/s]
# Epoch Progress:  66%|██████▌   | 329/500 [00:00<00:00, 826.93it/s]
# Epoch Progress:  83%|████████▎ | 413/500 [00:00<00:00, 830.44it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 717.13it/s]
# Experiment Progress:  95%|█████████▌| 95/100 [01:08<00:04,  1.19it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  17%|█▋        | 87/500 [00:00<00:00, 863.44it/s]
# Epoch Progress:  35%|███▌      | 175/500 [00:00<00:00, 869.51it/s]
# Epoch Progress:  53%|█████▎    | 265/500 [00:00<00:00, 882.05it/s]
# Epoch Progress:  71%|███████   | 354/500 [00:00<00:00, 868.07it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 747.84it/s]
# Experiment Progress:  96%|█████████▌| 96/100 [01:09<00:03,  1.26it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  18%|█▊        | 91/500 [00:00<00:00, 899.72it/s]
# Epoch Progress:  36%|███▌      | 181/500 [00:00<00:00, 896.41it/s]
# Epoch Progress:  54%|█████▍    | 271/500 [00:00<00:00, 895.29it/s]
# Epoch Progress:  72%|███████▏  | 361/500 [00:00<00:00, 868.37it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 755.82it/s]
# Experiment Progress:  97%|█████████▋| 97/100 [01:09<00:02,  1.32it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  17%|█▋        | 86/500 [00:00<00:00, 853.53it/s]
# Epoch Progress:  34%|███▍      | 172/500 [00:00<00:00, 855.29it/s]
# Epoch Progress:  52%|█████▏    | 258/500 [00:00<00:00, 852.96it/s]
# Epoch Progress:  69%|██████▉   | 344/500 [00:00<00:00, 849.02it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 740.51it/s]
# Experiment Progress:  98%|█████████▊| 98/100 [01:10<00:01,  1.35it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  18%|█▊        | 88/500 [00:00<00:00, 880.00it/s]
# Epoch Progress:  35%|███▌      | 176/500 [00:00<00:00, 865.06it/s]
# Epoch Progress:  53%|█████▎    | 264/500 [00:00<00:00, 869.12it/s]
# Epoch Progress:  70%|███████   | 351/500 [00:00<00:00, 857.22it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 744.69it/s]
# Experiment Progress:  99%|█████████▉| 99/100 [01:11<00:00,  1.38it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch Progress:  18%|█▊        | 92/500 [00:00<00:00, 916.86it/s]
# Epoch Progress:  37%|███▋      | 184/500 [00:00<00:00, 894.03it/s]
# Epoch Progress:  55%|█████▍    | 274/500 [00:00<00:00, 868.97it/s]
# Epoch Progress:  72%|███████▏  | 361/500 [00:00<00:00, 858.97it/s]
# Epoch Progress: 100%|██████████| 500/500 [00:00<00:00, 745.83it/s]
# Experiment Progress: 100%|██████████| 100/100 [01:12<00:00,  1.38it/s]
#     final error(train) = nan
#     final error(valid) = nan
#     final acc(train)   = 9.86e-02
#     final acc(valid)   = 9.91e-02
#     run time per epoch = 0.73
